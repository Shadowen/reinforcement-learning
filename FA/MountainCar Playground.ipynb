# %%
# %matplotlib inline

import gym
import numpy as np
from matplotlib import pyplot as plt

# %%
env = gym.envs.make("MountainCar-v0")
# Out:
# [2016-10-08 16:46:48,096] Making new env: MountainCar-v0

# %%
env.reset()
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(0) for x in range(10000)]
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

env.render(close=True)

# %%
env.step(0)
# Out:
# (array([-0.58572592,  0.01062842]), -1.0, False, {})
